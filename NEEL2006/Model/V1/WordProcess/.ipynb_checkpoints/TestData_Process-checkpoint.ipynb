# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import string
from sklearn.feature_extraction.text import CountVectorizer
import re

# %% [markdown]
# ## Test Data Process

# %%
test_data = pd.read_table('twitter_test.txt',header = None,sep='|')

# %%
test_data.columns=['None1','ID','Sentence','Entity','Label','None2']

# %% [markdown]
# #### Delete punctuation and stopwords

# %%
def text_process(sentence):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in sentence if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
test_data['Sentence'].apply(text_process)
bow_transformer = CountVectorizer(analyzer = text_process).fit(test_data['Sentence'])

# %% [markdown]
# #### Add a feature whether the entity's first letter is capital

# %%
def whetherIsCapital(entity):
    if entity.islower() == True:
        return '0'
    else:
        return '1'
test_data['WhetherIsCapital'] = test_data['Entity'].map(whetherIsCapital)

# %% [markdown]
# #### Delete Emoji

# %%
emoji_pattern = re.compile(u'[\U00010000-\U0010ffff]')

def remove_emoji(text):
    return emoji_pattern.sub(r'', text)

test_data['NewSentence']=test_data['Sentence'].map(remove_emoji)

# %%
test_data.iloc[77]['NewSentence']
# Out:
# "✨Getting so close, #TheForceAwakens. #StarWars marathon this weekend, yip I'm just that wild and crazy!  ✨ https://t.co/GKaSLCuAim"

# %%
emoji_pattern2 = re.compile(u'\U0001f601-\U0001f64f')
#sample_list = [u'\u2728']

def remove_emoji2(text):
    return emoji_pattern2.sub(r'', text)

#https://apps.timwhitlock.info/emoji/tables/unicode#

# %%
test_data['NewSentence']=test_data['NewSentence'].map(remove_emoji2)

# %%
test_data.iloc[160]['NewSentence']
# Out:
# 'Here you go @john_boyega. These pics always look better with the lightsaber glowing  #StarWars #TheForceAwakens #… https://t.co/KWS8YJ6dvR'

# %% [markdown]
# #### Delete URL

# %%
def delete_url(list1):
    new = []
    for word in list1:
        if (word.startswith('htt') == False):
            if(word.startswith('https') == False):
                new.append(word)
    return new

def sentence_delete_url(sentence):
    word = sentence.split()
    newlist = delete_url(word)
    newsentence = ' '.join(newlist)
    return newsentence

test_data['NewSentence']=test_data['NewSentence'].map(sentence_delete_url)

# %%
test_data
# Out:
#       None1                  ID  \
# 0       NaN  674869443671941120
# 1       NaN  674869443671941120
# 2       NaN  674869443671941120
# 3       NaN  674869443671941120
# 4       NaN  674869443671941120
# 5       NaN  674962184615682048
# 6       NaN  674962184615682048
# 7       NaN  674962184615682048
# 8       NaN  674962184615682048
# 9       NaN  674962728692400128
# 10      NaN  674962728692400128
# 11      NaN  674962728692400128
# 12      NaN  674962728692400128
# 13      NaN  674962728692400128
# 14      NaN  674962989980778496
# 15      NaN  674963112513028097
# 16      NaN  674963112513028097
# 17      NaN  674963112513028097
# 18      NaN  674963112513028097
# 19      NaN  674963112513028097
# 20      NaN  674963400221442048
# 21      NaN  674963400221442048
# 22      NaN  674963400221442048
# 23      NaN  674963400221442048
# 24      NaN  674963723946184705
# 25      NaN  674963723946184705
# 26      NaN  674963903546302465
# 27      NaN  674963903546302465
# 1001  @MovieManMenzel Star Wars The Force Awakens Re...
# 1002  @MovieManMenzel Star Wars The Force Awakens Re...
# 1003  @MovieManMenzel Star Wars The Force Awakens Re...
# 1004  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1005  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1006  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1007  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1008  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1009  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1010  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1011  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1012  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1013  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1014  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1015              Star Wars Day https://t.co/e27hMipoJo
# 1016  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1017  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1018  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1019  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1020  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1021  RT @akyeneba_joey: i wish you a #PulseMania Xm...
#
#                                           Entity         Label  None2  \
# 0                                       Egyptian         Thing    NaN
# 1                                          Obama        Person    NaN
# 2                                    chirofrenzy        Person    NaN
# 3                                  EntheosShines        Person    NaN
# 4                                     PatVPeters        Person    NaN
# 5                                      Star Wars       Product    NaN
# 6                                       StarWars       Product    NaN
# 7                                TheForceAwakens       Product    NaN
# 8                                Rick_OntheRocks        Person    NaN
# 9                                       starwars       Product    NaN
# 10                                         force         Thing    NaN
# 11                                    regentsuni  Organization    NaN
# 12                                        Regent  Organization    NaN
# 13                                   rjmcculloch        Person    NaN
# 14                                      starwars       Product    NaN
# 15                                      StarWars       Product    NaN
# 16                                     LAriola25        Person    NaN
# 17                                NatalieBrookeJ        Person    NaN
# 18                                     bennyB522        Person    NaN
# 19                                     Breeskiis        Person    NaN
# 20                                      StarWars       Product    NaN
# 21                               TheForceAwakens       Product    NaN
# 22                                     DawnCullo        Person    NaN
# 23      Star Wars: The Force Awakens Press Event         Event    NaN
# 24                                      StarWars       Product    NaN
# 25                               TheForceAwakens       Product    NaN
# 26                                      starwars       Product    NaN
# 27                                        malick        Person    NaN
# 28                                      starwars       Product    NaN
# 29                                Star Wars 1313       Product    NaN
# ...                                          ...           ...    ...
# 992                                     StarWars       Product    NaN
# 993                                    The force         Thing    NaN
# 994                                     starwars       Product    NaN
# 995                                      DeanWye  Organization    NaN
# 996                                  deanwyefilm  Organization    NaN
# 997                              TheForceAwakens       Product    NaN
# 998                  Star Wars The Force Awakens       Product    NaN
# 999                                     StarWars       Product    NaN
# 1000                             TheForceAwakens       Product    NaN
# 1001                        StarWarsForceAwakens       Product    NaN
# 1002                                    StarWars       Product    NaN
# 1003                              MovieManMenzel        Person    NaN
# 1004                                        IMDb  Organization    NaN
# 1005                                    starwars       Product    NaN
# 1006                             TheForceAwakens       Product    NaN
# 1004                1  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1005                0  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1006                1  RT @IMDb: #BoxOffice:' @starwars: #TheForceAwa...
# 1007                1  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1008                1  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1009                1  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1010                1  TheFilmFile Review: STAR WARS: EPISODE VII - T...
# 1011                1  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1012                0  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1013                1  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1014                1  RT @702sydney: #StarWars #TheForceAwakens prem...
# 1015                1                                      Star Wars Day
# 1016                1  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1017                0  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1018                0  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1019                0  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1020                1  RT @akyeneba_joey: i wish you a #PulseMania Xm...
# 1021                0  RT @akyeneba_joey: i wish you a #PulseMania Xm...
#
# [1022 rows x 8 columns]

# %% [markdown]
# #### Add a feature : length of NewSentence

# %%
def calculateLength(Sentence):
    return len(Sentence)

# %%
test_data['SentenceLength'] = test_data['NewSentence'].map(calculateLength)

# %% [markdown]
# #### Delete useless columns: only keep: NewSentence,Entity,WhetherIsCapital and Length

# %%
test_data.drop(test_data.columns[0:2],axis=1,inplace = True)

# %%
test_data.drop(test_data[['Sentence','None2','Label']],axis = 1,inplace = True)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 4 columns):
# Entity              1022 non-null object
# WhetherIsCapital    1022 non-null object
# NewSentence         1022 non-null object
# SentenceLength      1022 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 32.0+ KB

# %% [markdown]
# #### Extract NewSentence and Entity as test_Sentence.txt and test_Entity.txt

# %%
test_sentence = test_data.copy()

# %%
#test_sentence.head(20)
test_sentence.drop(test_sentence[['Entity','WhetherIsCapital']],axis=1,inplace=True)

# %%
test_sentence.drop(test_sentence[['SentenceLength']],axis=1,inplace=True)

# %%
test_sentence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 1 columns):
# NewSentence    1022 non-null object
# dtypes: object(1)
# memory usage: 8.1+ KB

# %%
test_data.drop(test_data[['NewSentence']],axis=1,inplace=True)

# %%
test_sentence.to_csv('test_sentence.txt',index = False)

# %%
test_entity = test_data.copy()

# %%
test_entity.drop(test_entity[['WhetherIsCapital','SentenceLength']],axis=1,inplace=True)

# %%
test_entity.to_csv('test_entity.txt',index = False)

# %%
test_data.drop(test_data[['Entity']],axis=1,inplace=True)

# %%
test_data.to_csv('test_Capital_and_Length.txt',index = False,sep=' ')

# %% [markdown]
# ### Get start end position of entity

# %%
test_data_neel =  pd.read_table('NEEL2016-test_neel.gs',header = None,sep='\t')

# %%
test_data_neel.drop(test_data_neel.columns[2],axis=1,inplace=True)

# %%
test_data_neel.to_csv('test_start_and_end_position_of_label.txt',index= False,sep=' ')
